# %%
# import cudf
# %load_ext cudf.pandas
import numpy as np
import pandas as pd

# %%
# Load all the data
# Project_Files/Finetune/Data/disease_features.csv Project_Files/Finetune/Data/drug_features.csv Project_Files/Finetune/Data/edges.csv Project_Files/Finetune/Data/kg_giant.csv Project_Files/Finetune/Data/kg_grouped_diseases_bert_map.csv Project_Files/Finetune/Data/kg_grouped_diseases.csv Project_Files/Finetune/Data/kg_grouped.csv Project_Files/Finetune/Data/kg_raw.csv Project_Files/Finetune/Data/kg.csv Project_Files/Finetune/Data/nodes.csv

disease_features = pd.read_csv("/home/ubuntu/Project_Files/Finetune/Data/disease_features.csv", low_memory=False)
drug_features = pd.read_csv("/home/ubuntu/Project_Files/Finetune/Data/drug_features.csv", low_memory=False)
edges = pd.read_csv("/home/ubuntu/Project_Files/Finetune/Data/edges.csv", low_memory=False)
kg_giant = pd.read_csv("/home/ubuntu/Project_Files/Finetune/Data/kg_giant.csv", low_memory=False)
kg_grouped_diseases_bert_map = pd.read_csv("/home/ubuntu/Project_Files/Finetune/Data/kg_grouped_diseases_bert_map.csv", low_memory=False)
kg_grouped_diseases = pd.read_csv("/home/ubuntu/Project_Files/Finetune/Data/kg_grouped_diseases.csv", low_memory=False)
kg_grouped = pd.read_csv("/home/ubuntu/Project_Files/Finetune/Data/kg_grouped.csv", low_memory=False)
kg_raw = pd.read_csv("/home/ubuntu/Project_Files/Finetune/Data/kg_raw.csv", low_memory=False)
kg = pd.read_csv("/home/ubuntu/Project_Files/Finetune/Data/kg.csv", low_memory=False)
nodes = pd.read_csv("/home/ubuntu/Project_Files/Finetune/Data/nodes.csv", low_memory=False)

# %%
# Summarize the data
disease_features.info()
print(disease_features.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44133 entries, 0 to 44132
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   node_index                         44133 non-null  int64
#  1   mondo_id                           44133 non-null  int64
#  2   mondo_name                         44133 non-null  object
#  3   group_id_bert                      13101 non-null  object
#  4   group_name_bert                    13101 non-null  object
#  5   mondo_definition                   35454 non-null  object
#  6   umls_description                   29968 non-null  object
#  7   orphanet_definition                15234 non-null  object
#  8   orphanet_prevalence                9141 non-null   object
#  9   orphanet_epidemiology              6952 non-null   object
#  10  orphanet_clinical_description      6920 non-null   object
# ...

# %%
drug_features.info()
print(drug_features.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7957 entries, 0 to 7956
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   node_index           7957 non-null   int64
#  1   description          4591 non-null   object
#  2   half_life            2063 non-null   object
#  3   indication           3393 non-null   object
#  4   mechanism_of_action  3242 non-null   object
#  5   protein_binding      1669 non-null   object
#  6   pharmacodynamics     2659 non-null   object
#  7   state                6517 non-null   object
#  8   atc_1                2818 non-null   object
#  9   atc_2                2818 non-null   object
#  10  atc_3                2818 non-null   object
#  11  atc_4                2818 non-null   object
#  12  category             5431 non-null   object
#  13  group                7957 non-null   object
#  14  pathway              598 non-null    object
# ...

# %%
edges.info()
print(edges.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8100498 entries, 0 to 8100497
# Data columns (total 4 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   relation          object
#  1   display_relation  object
#  2   x_index           int64
#  3   y_index           int64
# dtypes: int64(2), object(2)
# memory usage: 247.2+ MB
#           relation display_relation  x_index  y_index
# 0  protein_protein              ppi        0     8889
# 1  protein_protein              ppi        1     2798
# 2  protein_protein              ppi        2     5646
# 3  protein_protein              ppi        3    11592
# 4  protein_protein              ppi        4     2122

# %%
kg_giant.info()
print(kg_giant.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8196862 entries, 0 to 8196861
# Data columns (total 10 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   relation          object
#  1   display_relation  object
#  2   x_id              object
#  3   x_type            object
#  4   x_name            object
#  5   x_source          object
#  6   y_id              object
#  7   y_type            object
#  8   y_name            object
#  9   y_source          object
# dtypes: object(10)
# memory usage: 625.4+ MB
#           relation display_relation  x_id        x_type  x_name x_source  \
# 0  protein_protein              ppi  9796  gene/protein  PHYHIP     NCBI
# 1  protein_protein              ppi  7918  gene/protein  GPANK1     NCBI
# 2  protein_protein              ppi  8233  gene/protein   ZRSR2     NCBI
# 3  protein_protein              ppi  4899  gene/protein    NRF1     NCBI
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 5 sns.countplot(x='disease_id', data=kg_giant)
#       6 plt.show()
#
# NameError: name 'kg_giant' is not defined

# %%
kg_grouped_diseases_bert_map.info()
print(kg_grouped_diseases_bert_map.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6392 entries, 0 to 6391
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   node_id          6392 non-null   int64
#  1   node_type        6392 non-null   object
#  2   node_name        6392 non-null   object
#  3   node_source      6392 non-null   object
#  4   group_name_auto  6392 non-null   object
#  5   group_name_bert  6392 non-null   object
#  6   group_id_bert    6392 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 349.7+ KB
#    node_id node_type                        node_name node_source  \
# 0    13924   disease  osteogenesis imperfecta type 13       MONDO
# 1    12592   disease  osteogenesis imperfecta type 11       MONDO
# 2    14672   disease  osteogenesis imperfecta type 17       MONDO
# 3    13460   disease  osteogenesis imperfecta type 12       MONDO
# 4    12591   disease   osteogenesis imperfecta type 5       MONDO
# ...

# %%
kg_grouped_diseases.info()
print(kg_grouped_diseases.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22205 entries, 0 to 22204
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   node_id          22205 non-null  int64
#  1   node_type        22205 non-null  object
#  2   node_name        22205 non-null  object
#  3   node_source      22205 non-null  object
#  4   group_name_auto  22205 non-null  object
#  5   group_name_bert  22205 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1.0+ MB
#    node_id node_type                                          node_name  \
# 0    13924   disease                    osteogenesis imperfecta type 13
# 1    11160   disease       autosomal recessive nonsyndromic deafness 15
# 2     8099   disease  congenital stationary night blindness autosoma...
# 3    14854   disease        autosomal dominant nonsyndromic deafness 66
# 4    33202   disease                  deafness, autosomal recessive 109
#
# ...

# %%
kg_grouped.info()
print(kg_grouped.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8100498 entries, 0 to 8100497
# Data columns (total 10 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   relation          object
#  1   display_relation  object
#  2   x_id              object
#  3   x_type            object
#  4   x_name            object
#  5   x_source          object
#  6   y_id              object
#  7   y_type            object
#  8   y_name            object
#  9   y_source          object
# dtypes: object(10)
# memory usage: 618.0+ MB
#           relation display_relation  x_id        x_type  x_name x_source  \
# 0  protein_protein              ppi  9796  gene/protein  PHYHIP     NCBI
# 1  protein_protein              ppi  7918  gene/protein  GPANK1     NCBI
# 2  protein_protein              ppi  8233  gene/protein   ZRSR2     NCBI
# 3  protein_protein              ppi  4899  gene/protein    NRF1     NCBI
# ...

# %%
kg_raw.info()
print(kg_raw.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8197026 entries, 0 to 8197025
# Data columns (total 10 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   relation          object
#  1   display_relation  object
#  2   x_id              object
#  3   x_type            object
#  4   x_name            object
#  5   x_source          object
#  6   y_id              object
#  7   y_type            object
#  8   y_name            object
#  9   y_source          object
# dtypes: object(10)
# memory usage: 625.4+ MB
#           relation display_relation  x_id        x_type  x_name x_source  \
# 0  protein_protein              ppi  9796  gene/protein  PHYHIP     NCBI
# 1  protein_protein              ppi  7918  gene/protein  GPANK1     NCBI
# 2  protein_protein              ppi  8233  gene/protein   ZRSR2     NCBI
# 3  protein_protein              ppi  4899  gene/protein    NRF1     NCBI
# ...

# %%
unique_relations = kg_raw['relation'].unique()
print(unique_relations)

unique_relations_display = kg_raw['display_relation'].unique()
print(unique_relations_display)
# Out:
# ['protein_protein' 'drug_protein' 'contraindication' 'indication'
#  'off-label use' 'drug_drug' 'phenotype_protein' 'phenotype_phenotype'
#  'disease_phenotype_negative' 'disease_phenotype_positive'
#  'disease_protein' 'disease_disease' 'drug_effect' 'bioprocess_bioprocess'
#  'molfunc_molfunc' 'cellcomp_cellcomp' 'molfunc_protein'
#  'cellcomp_protein' 'bioprocess_protein' 'exposure_protein'
#  'exposure_disease' 'exposure_exposure' 'exposure_bioprocess'
#  'exposure_molfunc' 'exposure_cellcomp' 'pathway_pathway'
#  'pathway_protein' 'anatomy_anatomy' 'anatomy_protein_present'
#  'anatomy_protein_absent']
# ['ppi' 'carrier' 'enzyme' 'target' 'transporter' 'contraindication'
#  'indication' 'off-label use' 'synergistic interaction' 'associated with'
#  'parent-child' 'phenotype absent' 'phenotype present' 'side effect'
#  'interacts with' 'linked to' 'expression present' 'expression absent']

# %%
# Plot of counts of each relation
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
ax = sns.countplot(x="display_relation", data=kg_raw)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
ax = sns.countplot(x="relation", data=kg_raw)
plt.xticks(rotation=90)
plt.show()

# %%
kg.info()
print(kg.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8100498 entries, 0 to 8100497
# Data columns (total 12 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   relation          object
#  1   display_relation  object
#  2   x_index           int64
#  3   x_id              object
#  4   x_type            object
#  5   x_name            object
#  6   x_source          object
#  7   y_index           int64
#  8   y_id              object
#  9   y_type            object
#  10  y_name            object
#  11  y_source          object
# dtypes: int64(2), object(10)
# memory usage: 741.6+ MB
#           relation display_relation  x_index  x_id        x_type  x_name  \
# 0  protein_protein              ppi        0  9796  gene/protein  PHYHIP
# 1  protein_protein              ppi        1  7918  gene/protein  GPANK1
# 2  protein_protein              ppi        2  8233  gene/protein   ZRSR2
# 3  protein_protein              ppi        3  4899  gene/protein    NRF1
# ...

# %%
nodes.info()
print(nodes.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129375 entries, 0 to 129374
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   node_index   129375 non-null  int64
#  1   node_id      129375 non-null  object
#  2   node_type    129375 non-null  object
#  3   node_name    129375 non-null  object
#  4   node_source  129375 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.9+ MB
#    node_index node_id     node_type node_name node_source
# 0           0    9796  gene/protein    PHYHIP        NCBI
# 1           1    7918  gene/protein    GPANK1        NCBI
# 2           2    8233  gene/protein     ZRSR2        NCBI
# 3           3    4899  gene/protein      NRF1        NCBI
# 4           4    5297  gene/protein     PI4KA        NCBI
